# %% [markdown]
# # Kaggle
# ## Competição DSA de Machine Learning - Dezembro 2019

# %% [markdown]
# Versão 1.0.0: LB = 0.48866 CV = 0.463102
# - modelo: LightGBM (com algumas otimizações)
# - features engineering: gerado através do Auto_ViML
#
# Versão 1.0.1: LB = 0.48991 CV = 0.462946
# - modelo: LightGBM (com algumas otimizações)
# - features engineering: gerado através do Auto_ViML (com novas features)
#
# Versão 1.0.2: LB = 0.48915 CV = 0.464442
# - modelo: LightGBM (com algumas otimizações)
# - features engineering: gerado através do Auto_ViML (com agrupamento pela coluna v2)
#
# Versão 1.0.3: LB = 0.88299 CV = 0.344659
# - modelo: LightGBM (com algumas otimizações)
# - features engineering: gerado interno
#
# Versão 1.0.4: LB = 0.6041 CV = 0.461724
# - modelo: LightGBM (com algumas otimizações)
# - features engineering: gerado através do Auto_ViML (modificado v1)
#
# Versão 1.0.5: LB = 0.48897 CV = 0.466055 (kfold)   CV = 0.466422 (StratifiedKFold)
# - modelo: LightGBM (com algumas otimizações)
# - features engineering: gerado com pacotes estatisticos

# %% [markdown]
# # Importando as bibliotecas

# %%
# Importar os principais pacotes
import numpy as np
import pandas as pd
import itertools
import seaborn as sns
sns.set()

import matplotlib.pyplot as plt
# %matplotlib inline

import time
import datetime
import gc

# Evitar que aparece os warnings
import warnings
warnings.filterwarnings("ignore")

# Seta algumas opções no Jupyter para exibição dos datasets
pd.set_option('display.max_columns', 200)
pd.set_option('display.max_rows', 200)

# Variavel para controlar o treinamento no Kaggle
TRAIN_OFFLINE = True

# %%
# Importa os pacotes de algoritmos
import lightgbm as lgb
from lightgbm.sklearn import LGBMClassifier

# Importa pacotes do sklearn
from sklearn.ensemble import RandomForestClassifier
from sklearn import preprocessing
from sklearn.model_selection import train_test_split, GridSearchCV, KFold, StratifiedKFold
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_auc_score, log_loss
from sklearn.preprocessing import scale, MinMaxScaler, StandardScaler

# %% [markdown]
# # Carregando os dados de treino e teste

# %%
def read_data():
    
    print('Carregando arquivo dataset_treino_new.csv....')
    train = pd.read_csv('../dataset/dataset_treino_new.csv')
    print('dataset_treino.csv tem {} linhas and {} colunas'.format(train.shape[0], train.shape[1]))

    print('Carregando arquivo dataset_teste_new.csv....')
    test = pd.read_csv('../dataset/dataset_teste_new.csv')
    print('dataset_teste.csv tem {} linhas and {} colunas'.format(test.shape[0], test.shape[1]))
    
    return train, test

# %%
# Leitura dos dados
train, test = read_data()
# Out:
# Carregando arquivo dataset_treino_new.csv....
# dataset_treino.csv tem 114321 linhas and 192 colunas
# Carregando arquivo dataset_teste_new.csv....
# dataset_teste.csv tem 114393 linhas and 192 colunas

# %%
train.head()
# Out:
#    target        v1       v10       v100      v101      v102      v103  \
# 0     1.0  1.335739  0.503281  19.470199  8.389237  2.757375  4.374296
# 1     1.0  1.629654  1.312910  12.085858  6.860181  2.892925  5.300739
# 2     1.0  0.943877  0.765864  15.491329  5.879353  3.292788  5.924457
# 2  4132.407778  16.846740  8.007440 -0.002375 -0.638238  -915.137928
# 3   866.625744  26.144116 -3.687951 -0.000718 -3.292667  -190.147106
# 4  4672.074711  24.058351 -0.387866  0.000394 -1.091193  -989.561933
#
#       srp_11    pca_12    ica_12   tsvd_12       grp_12     srp_12
# 0  16.414498  0.287991  0.000181  1.813369 -8354.976687 -41.686171
# 1  17.560602  0.392828  0.000237  0.624377 -3820.622435 -39.469108
# 2  20.288315 -0.591242 -0.000435 -8.190430 -3539.810399 -41.178446
# 3  17.003139  1.443903  0.000916  1.637239  -729.001495 -41.094768
# 4  16.653962  1.343012  0.000851  0.070965 -3959.562617 -42.898538

# %% [markdown]
# # Algoritmo LigthGBM

# %%
# Configurações Gerais

GENERATE_SUBMISSION_FILES = True
SUBMISSION_SUFIX = "_lgbm_v.1.0.5"
STRATIFIED_KFOLD = False
RANDOM_SEED = 12345 #737851
NUM_THREADS = 4
NUM_FOLDS = 10
EARLY_STOPPING = 100

LIGHTGBM_PARAMS = {
    'boosting_type': 'goss',
    'n_estimators': 10000,
    'learning_rate': 0.005134,
    'num_leaves': 54,
    'max_depth': 10,
    'subsample_for_bin': 240000,
    'reg_alpha': 0.436193,
    'reg_lambda': 0.479169,
    'colsample_bytree': 0.508716,
    'min_split_gain': 0.024766,
    'subsample': 1,
    'is_unbalance': False,
    'silent':-1,
    'verbose':-1
}

# %%
# ------------------------- LIGHTGBM MODEL -------------------------

def run_model(data, categorical_feature = None):
    df = data[data['target'].notnull()]
    test = data[data['target'].isnull()]
    del_features = ['target']
    predictors = list(filter(lambda v: v not in del_features, df.columns))
    
    print("Train/valid shape: {}, test shape: {}".format(df.shape, test.shape))

    if not STRATIFIED_KFOLD:
        folds = KFold(n_splits= NUM_FOLDS, shuffle=True, random_state= RANDOM_SEED)
    else:
        folds = StratifiedKFold(n_splits= NUM_FOLDS, shuffle=True, random_state= RANDOM_SEED)

    # Hold oof predictions, test predictions, feature importance and training/valid auc
    oof_preds = np.zeros(df.shape[0])
    sub_preds = np.zeros(test.shape[0])
    importance_df = pd.DataFrame()
    eval_results = dict()

    for n_fold, (train_idx, valid_idx) in enumerate(folds.split(df[predictors], df['target'])):
        train_x, train_y = df[predictors].iloc[train_idx], df['target'].iloc[train_idx]
        valid_x, valid_y = df[predictors].iloc[valid_idx], df['target'].iloc[valid_idx]

        params = {'random_state': RANDOM_SEED, 'nthread': NUM_THREADS}
        clf = LGBMClassifier(**{**params, **LIGHTGBM_PARAMS})
        if not categorical_feature:
            clf.fit(train_x, train_y, eval_set=[(train_x, train_y), (valid_x, valid_y)],
                    eval_metric='logloss', verbose=400, early_stopping_rounds= EARLY_STOPPING)
        else:
            clf.fit(train_x, train_y, eval_set=[(train_x, train_y), (valid_x, valid_y)],
                    eval_metric='logloss', verbose=400, early_stopping_rounds=EARLY_STOPPING,
                    feature_name= list(df[predictors].columns), categorical_feature= categorical_feature)

        oof_preds[valid_idx] = clf.predict_proba(valid_x, num_iteration=clf.best_iteration_)[:, 1]
        sub_preds += clf.predict_proba(test[predictors], num_iteration=clf.best_iteration_)[:, 1] / folds.n_splits

        # Feature importance by GAIN and SPLIT
        fold_importance = pd.DataFrame()
        fold_importance["feature"] = predictors
        fold_importance["gain"] = clf.booster_.feature_importance(importance_type='gain')
        fold_importance["split"] = clf.booster_.feature_importance(importance_type='split')
        importance_df = pd.concat([importance_df, fold_importance], axis=0)
        eval_results['train_{}'.format(n_fold+1)]  = clf.evals_result_['training']['binary_logloss']
        eval_results['valid_{}'.format(n_fold+1)] = clf.evals_result_['valid_1']['binary_logloss']

        print('Fold %2d Log Loss : %.6f' % (n_fold + 1, log_loss(valid_y, oof_preds[valid_idx])))
        del clf, train_x, train_y, valid_x, valid_y
        gc.collect()

    print('Full Log Loss score %.6f' % log_loss(df['target'], oof_preds))
    test['target'] = sub_preds.copy()

    # Get the average feature importance between folds
    mean_importance = importance_df.groupby('feature').mean().reset_index()
    mean_importance.sort_values(by= 'gain', ascending=False, inplace=True)
    # Save feature importance, test predictions and oof predictions as csv
    if GENERATE_SUBMISSION_FILES:

        # Save submission (test data) and feature importance
        submission = pd.read_csv('../dataset/sample_submission.csv')
        submission['PredictedProb'] = sub_preds.copy()
        submission.to_csv('../submission/submission{}.csv'.format(SUBMISSION_SUFIX), index=False)
        
        mean_importance.to_csv('feature_importance{}.csv'.format(SUBMISSION_SUFIX), index=False)
        plt.hist(submission.PredictedProb)
        plt.show()
    return mean_importance

# %%
mean_importance = run_model(df)
# Out:
# Train/valid shape: (114321, 192), test shape: (114393, 192)
# Training until validation scores don't improve for 100 rounds
# [400]	training's binary_logloss: 0.469252	valid_1's binary_logloss: 0.479595
# [800]	training's binary_logloss: 0.451786	valid_1's binary_logloss: 0.47219
# [1200]	training's binary_logloss: 0.439504	valid_1's binary_logloss: 0.469942
# [1600]	training's binary_logloss: 0.428804	valid_1's binary_logloss: 0.468772
# [2000]	training's binary_logloss: 0.418965	valid_1's binary_logloss: 0.46792
# [2400]	training's binary_logloss: 0.409897	valid_1's binary_logloss: 0.467579
# Early stopping, best iteration is:
# [2685]	training's binary_logloss: 0.403871	valid_1's binary_logloss: 0.467023
# Fold  1 Log Loss : 0.467023
# Training until validation scores don't improve for 100 rounds
# [400]	training's binary_logloss: 0.470035	valid_1's binary_logloss: 0.472184
# [800]	training's binary_logloss: 0.452393	valid_1's binary_logloss: 0.465192
# [1200]	training's binary_logloss: 0.440134	valid_1's binary_logloss: 0.463348
# [1600]	training's binary_logloss: 0.429385	valid_1's binary_logloss: 0.462457
# [2000]	training's binary_logloss: 0.419647	valid_1's binary_logloss: 0.461883
# [2400]	training's binary_logloss: 0.410612	valid_1's binary_logloss: 0.461307
# Early stopping, best iteration is:
# [2637]	training's binary_logloss: 0.405544	valid_1's binary_logloss: 0.461127
# Fold  2 Log Loss : 0.461127
# Training until validation scores don't improve for 100 rounds
# [400]	training's binary_logloss: 0.469216	valid_1's binary_logloss: 0.477772
# [800]	training's binary_logloss: 0.451466	valid_1's binary_logloss: 0.470576
# [1200]	training's binary_logloss: 0.43929	valid_1's binary_logloss: 0.468241
# [1600]	training's binary_logloss: 0.428618	valid_1's binary_logloss: 0.46701
# [2000]	training's binary_logloss: 0.418951	valid_1's binary_logloss: 0.466311
# [2400]	training's binary_logloss: 0.410013	valid_1's binary_logloss: 0.465709
# [2800]	training's binary_logloss: 0.401613	valid_1's binary_logloss: 0.465341
# [3200]	training's binary_logloss: 0.393611	valid_1's binary_logloss: 0.464947
# Early stopping, best iteration is:
# [3374]	training's binary_logloss: 0.390314	valid_1's binary_logloss: 0.464794
# Fold  3 Log Loss : 0.464794
# Training until validation scores don't improve for 100 rounds
# [400]	training's binary_logloss: 0.469186	valid_1's binary_logloss: 0.479174
# [800]	training's binary_logloss: 0.451498	valid_1's binary_logloss: 0.472132
# [1200]	training's binary_logloss: 0.439345	valid_1's binary_logloss: 0.470001
# [1600]	training's binary_logloss: 0.428655	valid_1's binary_logloss: 0.468917
# [2000]	training's binary_logloss: 0.418883	valid_1's binary_logloss: 0.468204
# [2400]	training's binary_logloss: 0.409818	valid_1's binary_logloss: 0.467562
# [2800]	training's binary_logloss: 0.401443	valid_1's binary_logloss: 0.467104
# Early stopping, best iteration is:
# [3034]	training's binary_logloss: 0.396765	valid_1's binary_logloss: 0.466705
# Fold  4 Log Loss : 0.466705
# Training until validation scores don't improve for 100 rounds
# [400]	training's binary_logloss: 0.469539	valid_1's binary_logloss: 0.477456
# [800]	training's binary_logloss: 0.451977	valid_1's binary_logloss: 0.469594
# [1200]	training's binary_logloss: 0.439856	valid_1's binary_logloss: 0.467497
# [1600]	training's binary_logloss: 0.42923	valid_1's binary_logloss: 0.466017
# [2000]	training's binary_logloss: 0.419565	valid_1's binary_logloss: 0.465233
# [2400]	training's binary_logloss: 0.41043	valid_1's binary_logloss: 0.464407
# [2800]	training's binary_logloss: 0.401993	valid_1's binary_logloss: 0.463755
# [3200]	training's binary_logloss: 0.394053	valid_1's binary_logloss: 0.463086
# [3600]	training's binary_logloss: 0.386579	valid_1's binary_logloss: 0.462775
# [4000]	training's binary_logloss: 0.379551	valid_1's binary_logloss: 0.462445
# Early stopping, best iteration is:
# [4132]	training's binary_logloss: 0.377286	valid_1's binary_logloss: 0.462296
# Fold  5 Log Loss : 0.462296
# Training until validation scores don't improve for 100 rounds
# [400]	training's binary_logloss: 0.468807	valid_1's binary_logloss: 0.480889
# [800]	training's binary_logloss: 0.451165	valid_1's binary_logloss: 0.474687
# [1200]	training's binary_logloss: 0.43905	valid_1's binary_logloss: 0.472826
# [1600]	training's binary_logloss: 0.428323	valid_1's binary_logloss: 0.471782
# Early stopping, best iteration is:
# [1760]	training's binary_logloss: 0.424357	valid_1's binary_logloss: 0.471406
# Fold  6 Log Loss : 0.471406
# Training until validation scores don't improve for 100 rounds
# [400]	training's binary_logloss: 0.470546	valid_1's binary_logloss: 0.468611
# [800]	training's binary_logloss: 0.452958	valid_1's binary_logloss: 0.460179
# [1200]	training's binary_logloss: 0.440754	valid_1's binary_logloss: 0.457603
# [1600]	training's binary_logloss: 0.430113	valid_1's binary_logloss: 0.456272
# [2000]	training's binary_logloss: 0.420365	valid_1's binary_logloss: 0.455202
# [2400]	training's binary_logloss: 0.411383	valid_1's binary_logloss: 0.454331
# [2800]	training's binary_logloss: 0.40295	valid_1's binary_logloss: 0.453465
# Early stopping, best iteration is:
# [3022]	training's binary_logloss: 0.398471	valid_1's binary_logloss: 0.453047
# Fold  7 Log Loss : 0.453047
# Training until validation scores don't improve for 100 rounds
# [400]	training's binary_logloss: 0.468213	valid_1's binary_logloss: 0.486675
# [800]	training's binary_logloss: 0.450724	valid_1's binary_logloss: 0.479814
# [1200]	training's binary_logloss: 0.438536	valid_1's binary_logloss: 0.47762
# [1600]	training's binary_logloss: 0.427773	valid_1's binary_logloss: 0.476044
# [2000]	training's binary_logloss: 0.418107	valid_1's binary_logloss: 0.475481
# [2400]	training's binary_logloss: 0.409107	valid_1's binary_logloss: 0.475029
# [2800]	training's binary_logloss: 0.400683	valid_1's binary_logloss: 0.474596
# Early stopping, best iteration is:
# [3040]	training's binary_logloss: 0.3959	valid_1's binary_logloss: 0.474293
# Fold  8 Log Loss : 0.474293
# Training until validation scores don't improve for 100 rounds
# [400]	training's binary_logloss: 0.468876	valid_1's binary_logloss: 0.481801
# [800]	training's binary_logloss: 0.451231	valid_1's binary_logloss: 0.473954
# [1200]	training's binary_logloss: 0.438922	valid_1's binary_logloss: 0.471535
# [1600]	training's binary_logloss: 0.428295	valid_1's binary_logloss: 0.470317
# [2000]	training's binary_logloss: 0.41855	valid_1's binary_logloss: 0.469308
# [2400]	training's binary_logloss: 0.409558	valid_1's binary_logloss: 0.468601
# [2800]	training's binary_logloss: 0.401221	valid_1's binary_logloss: 0.468065
# [3200]	training's binary_logloss: 0.393414	valid_1's binary_logloss: 0.467735
# Early stopping, best iteration is:
# [3139]	training's binary_logloss: 0.394579	valid_1's binary_logloss: 0.467733
# Fold  9 Log Loss : 0.467733
# Training until validation scores don't improve for 100 rounds
# [400]	training's binary_logloss: 0.468717	valid_1's binary_logloss: 0.482747
# [800]	training's binary_logloss: 0.451059	valid_1's binary_logloss: 0.47671
# [1200]	training's binary_logloss: 0.438893	valid_1's binary_logloss: 0.474882
# [1600]	training's binary_logloss: 0.428113	valid_1's binary_logloss: 0.473815
# [2000]	training's binary_logloss: 0.418447	valid_1's binary_logloss: 0.473096
# [2400]	training's binary_logloss: 0.409548	valid_1's binary_logloss: 0.472796
# [2800]	training's binary_logloss: 0.401146	valid_1's binary_logloss: 0.472449
# [3200]	training's binary_logloss: 0.393242	valid_1's binary_logloss: 0.472136
# Early stopping, best iteration is:
# [3194]	training's binary_logloss: 0.393363	valid_1's binary_logloss: 0.472129
# Fold 10 Log Loss : 0.472129
# Full Log Loss score 0.466055
